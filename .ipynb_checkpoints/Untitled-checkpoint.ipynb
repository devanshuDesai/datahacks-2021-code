# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import quandl
import pyfolio as pf

from tqdm import tqdm

#Split
from sklearn.model_selection import train_test_split,TimeSeriesSplit,GridSearchCV
#Feature selection / dimension reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFECV,SelectPercentile,mutual_info_classif
#Performance evaluation
from sklearn import metrics

# Classifiers
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import RidgeClassifier, SGDClassifier, LogisticRegression,PassiveAggressiveClassifier
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier

import warnings
warnings.filterwarnings('ignore')

quandl.ApiConfig.api_key = "WLMxat9y7vVtegz9ZEe5"
start = '2000-01-01'
end = '2020-04-30'

np.random.seed(seed=1)

# %%
import pandas as pd
import seaborn as sns
pd.options.display.max_rows = 999
# %matplotlib inline

# %%
series = pd.read_csv('data/series.csv')
series
# Out:
#              series_id                                               name  \
# 0               AAA10Y  Moodys Seasoned Aaa Corporate Bond Yield Relat...
# 1             ASEANTOT        Import Price Index: ASEAN - All commodities
# 2               BAA10Y  Moodys Seasoned Baa Corporate Bond Yield Relat...
# 3         BUSAPPWNSAUS        Business Applications for the United States
# 4       BUSAPPWNSAUSYY        Business Applications for the United States
# 5        CBUSAPPWNSAUS  Business Applications from Corporations for th...
# 6      CBUSAPPWNSAUSYY  Business Applications from Corporations for th...
# 7         CUUR0000SA0R  Consumer Price Index for All Urban Consumers: ...
# 8              DEXCHUS                 China / U.S. Foreign Exchange Rate
# 9              DEXJPUS                 Japan / U.S. Foreign Exchange Rate
# 10             DEXUSEU                  U.S. / Euro Foreign Exchange Rate
# 11             DEXUSUK                  U.S. / U.K. Foreign Exchange Rate
# 12              DFII10  10-Year Treasury Inflation-Indexed Security, C...
# 13              DFII20  20-Year Treasury Inflation-Indexed Security, C...
# 14              DFII30  30-Year Treasury Inflation-Indexed Security, C...
# 15               DFII5  5-Year Treasury Inflation-Indexed Security, Co...
# 16               DFII7  7-Year Treasury Inflation-Indexed Security, Co...
# 17              DLTIIT  Treasury Inflation-Indexed Long-Term Average Y...
# 18            DPCREDIT                                Primary Credit Rate
# 19              DPRIME                               Bank Prime Loan Rate
# 20              EECTOT  Import Price Index: European Union - All commo...
# 21                EFFR                       Effective Federal Funds Rate
# 22             EFFRVOL                     Effective Federal Funds Volume
# 23    FRGSHPUSM649NCIS                      Cass Freight Index: Shipments
# 24         GVIPT50002S  Gross Value Weighted Industrial Production: Fi...
# 25         GVIPT50030S  Gross Value Weighted Industrial Production: Fi...
# 26         GVIPT51000S  Gross Value Weighted Industrial Production: Co...
# 27         GVIPT51100S  Gross Value Weighted Industrial Production: Du...
# 28         GVIPT51110S  Gross Value Weighted Industrial Production: Au...
# 29         GVIPT51120S  Gross Value Weighted Industrial Production: Ot...
# 30         GVIPT51200S  Gross Value Weighted Industrial Production: No...
# 31         GVIPT52000S  Gross Value Weighted Industrial Production: Eq...
# 32         GVIPT52100S  Gross Value Weighted Industrial Production: Bu...
# 33         GVIPT521A3S  Gross Value Weighted Industrial Production: Bu...
# 34         GVIPT52300S  Gross Value Weighted Industrial Production: De...
# 35         GVIPT54000S  Gross Value Weighted Industrial Production: No...
# 36         GVIPT54100S  Gross Value Weighted Industrial Production: Co...
# 37         GVIPT54200S  Gross Value Weighted Industrial Production: Bu...
# 38         GVIPT54220S  Gross Value Weighted Industrial Production: Co...
# 39  INFECTDISEMVTRACKD  Equity Market Volatility: Infectious Disease T...
# 40                IOER                   Interest Rate on Excess Reserves
# 41                IORR                 Interest Rate on Required Reserves
# 42   MEDCPIM158SFRBCLE                        Median Consumer Price Index
# 43        MORTGAGE15US  15-Year Fixed Rate Mortgage Average in the Uni...
# 44        MORTGAGE30US  30-Year Fixed Rate Mortgage Average in the Uni...
# 45                OBFR                        Overnight Bank Funding Rate
# 46             OBFRVOL                      Overnight Bank Funding Volume
# 47     PCUADLVWRADLVWR  Producer Price Index by Industry: Delivery and...
# 48       PCUAINFOAINFO      Producer Price Index by Industry: Information
# 49         PCUAMUMAMUM  Producer Price Index by Industry: Total Mining...
# 50     PCUARETTRARETTR  Producer Price Index by Industry: Total Retail...
# 51         PCUASHCASHC  Producer Price Index by Industry: Selected Hea...
# 52     PCUASTDSVASTDSV  Producer Price Index by Industry: Other Select...
# 53     PCUATRADEATRADE  Producer Price Index by Industry: Total Trade ...
# 54     PCUATRANSATRANS  Producer Price Index by Industry: Transportati...
# 55     PCUATRNWRATRNWR  Producer Price Index by Industry: Transportati...
# 56     PCUATTDSVATTDSV  Producer Price Index by Industry: Services Les...
# 57     PCUAWHLTRAWHLTR  Producer Price Index by Industry: Total Wholes...
# 58         PCUOMFGOMFG  Producer Price Index by Industry: Total Manufa...
# 59         PCUOMINOMIN  Producer Price Index by Industry: Total Mining...
# 60   SFTPAGRM158SFRBSF                           San Francisco Tech Pulse
# 61                SOFR                   Secured Overnight Financing Rate
# 62             SOFRVOL                 Secured Overnight Financing Volume
# 63               SP500                                            S&P 500
# 64              T10YIE                   10-Year Breakeven Inflation Rate
# 65             TEDRATE                                         TED Spread
# 66      TLAACBW027NBOG                 Total Assets, All Commercial Banks
# 67      TLBACBW027NBOG            Total Liabilities, All Commercial Banks
# 68            TSIFRGHT              Freight Transportation Services Index
# 69              UNRATE                                  Unemployment Rate
# 70          WLEMUINDXD   Equity Market-related Economic Uncertainty Index
#
#                    frequency                              units  \
# 0                      Daily                            Percent
# 1                    Monthly                 Index Dec 2003=100
# 2                      Daily                            Percent
# 3    Weekly, Ending Saturday                             Number
# 4    Weekly, Ending Saturday       Percent Change from Year Ago
# 5    Weekly, Ending Saturday                             Number
# 6    Weekly, Ending Saturday       Percent Change from Year Ago
# 7                    Monthly                Index 1982-1984=100
# 8                      Daily    Chinese Yuan to One U.S. Dollar
# 9                      Daily    Japanese Yen to One U.S. Dollar
# 10                     Daily           U.S. Dollars to One Euro
# 11                     Daily  U.S. Dollars to One British Pound
# 12                     Daily                            Percent
# 13                     Daily                            Percent
# 14                     Daily                            Percent
# 15                     Daily                            Percent
# 16                     Daily                            Percent
# 17                     Daily                            Percent
# 18                     Daily                            Percent
# 19                     Daily                            Percent
# 20                   Monthly                     Index 2000=100
# 21                     Daily                            Percent
# 22                     Daily           Billions of U.S. Dollars
# 23                   Monthly                   Index Jan 1990=1
# 24                   Monthly        Billions of 2012 US Dollars
# 25                   Monthly        Billions of 2012 US Dollars
# 26                   Monthly        Billions of 2012 US Dollars
# 27                   Monthly        Billions of 2012 US Dollars
# 28                   Monthly        Billions of 2012 US Dollars
# 29                   Monthly        Billions of 2012 US Dollars
# 30                   Monthly        Billions of 2012 US Dollars
# 31                   Monthly        Billions of 2012 US Dollars
# 32                   Monthly        Billions of 2012 US Dollars
# 33                   Monthly        Billions of 2012 US Dollars
# 34                   Monthly        Billions of 2012 US Dollars
# 35                   Monthly        Billions of 2012 US Dollars
# 36                   Monthly        Billions of 2012 US Dollars
# 37                   Monthly        Billions of 2012 US Dollars
# 38                   Monthly        Billions of 2012 US Dollars
# 39              Daily, 7-Day                              Index
# 40              Daily, 7-Day                            Percent
# 41              Daily, 7-Day                            Percent
# 42                   Monthly      Percent Change at Annual Rate
# 43   Weekly, Ending Thursday                            Percent
# 44   Weekly, Ending Thursday                            Percent
# 45                     Daily                            Percent
# 46                     Daily           Billions of U.S. Dollars
# 47                   Monthly                 Index Dec 2006=100
# 48                   Monthly                 Index Dec 2006=100
# 49                   Monthly                 Index Dec 2006=100
# 50                   Monthly                 Index Dec 2006=100
# 51                   Monthly                 Index Dec 2006=100
# 52                   Monthly                 Index Dec 2006=100
# 53                   Monthly                 Index Dec 2006=100
# 54                   Monthly                 Index Dec 2006=100
# 55                   Monthly                 Index Dec 2006=100
# 56                   Monthly                 Index Dec 2006=100
# 57                   Monthly                 Index Dec 2006=100
# 58                   Monthly                 Index Dec 1984=100
# 59                   Monthly                 Index Dec 1984=100
# 60                   Monthly      Percent Change at Annual Rate
# 61                     Daily                            Percent
# 62                     Daily           Billions of U.S. Dollars
# 63              Daily, Close                              Index
# 64                     Daily                            Percent
# 65                     Daily                            Percent
# 66  Weekly, Ending Wednesday           Billions of U.S. Dollars
# 67  Weekly, Ending Wednesday           Billions of U.S. Dollars
# 68                   Monthly          Chain-type Index 2000=100
# 69                   Monthly                            Percent
# 70              Daily, 7-Day                              Index
#
#         seasonal_adjustment                                        Description
# 0   Not Seasonally Adjusted  Series is calculated as the spread between Moo...
# 1   Not Seasonally Adjusted  For more information, please see the Import/Ex...
# 2   Not Seasonally Adjusted  Series is calculated as the spread between Moo...
# 3   Not Seasonally Adjusted  Business Applications (BA): The core business ...
# 4   Not Seasonally Adjusted  Business Applications (BA): The core business ...
# 5   Not Seasonally Adjusted  Business Applications from Corporations (CBA):...
# 6   Not Seasonally Adjusted  Business Applications from Corporations (CBA):...
# 7   Not Seasonally Adjusted                                                NaN
# 8   Not Seasonally Adjusted  Noon buying rates in New York City for cable t...
# 9   Not Seasonally Adjusted  Noon buying rates in New York City for cable t...
# 10  Not Seasonally Adjusted  Noon buying rates in New York City for cable t...
# 11  Not Seasonally Adjusted  Noon buying rates in New York City for cable t...
# 12  Not Seasonally Adjusted  For further information regarding treasury con...
# 13  Not Seasonally Adjusted  For further information regarding treasury con...
# 14  Not Seasonally Adjusted  For further information regarding treasury con...
# 15  Not Seasonally Adjusted  For further information regarding treasury con...
# 16  Not Seasonally Adjusted  For further information regarding treasury con...
# 17  Not Seasonally Adjusted  Based on the unweighted average bid yields for...
# 18  Not Seasonally Adjusted  This data represent rate charged for discounts...
# 19  Not Seasonally Adjusted  Rate posted by a majority of top 25 (by assets...
# 20  Not Seasonally Adjusted  For more information, please see the Import/Ex...
# 21  Not Seasonally Adjusted  For additional historical federal funds rate d...
# 22  Not Seasonally Adjusted  The federal funds market consists of domestic ...
# 23  Not Seasonally Adjusted  The Cass Freight Index uses January 1990 as it...
# 24      Seasonally Adjusted                                                NaN
# 25      Seasonally Adjusted                                                NaN
# 26      Seasonally Adjusted                                                NaN
# 27      Seasonally Adjusted                                                NaN
# 28      Seasonally Adjusted                                                NaN
# 29      Seasonally Adjusted                                                NaN
# 30      Seasonally Adjusted                                                NaN
# 31      Seasonally Adjusted                                                NaN
# 32      Seasonally Adjusted                                                NaN
# 33      Seasonally Adjusted                                                NaN
# 34      Seasonally Adjusted                                                NaN
# 35      Seasonally Adjusted                                                NaN
# 36      Seasonally Adjusted                                                NaN
# 37      Seasonally Adjusted                                                NaN
# 38      Seasonally Adjusted                                                NaN
# 39  Not Seasonally Adjusted  Assessing the economic impact of the COVID-19 ...
# 40  Not Seasonally Adjusted  The interest rate on excess reserves (IOER rat...
# 41  Not Seasonally Adjusted  The interest rate on required reserves (IORR r...
# 42      Seasonally Adjusted  Median Consumer Price Index (CPI) is a measure...
# 43  Not Seasonally Adjusted  Data is provided "as is," with no warranties o...
# 44  Not Seasonally Adjusted  Data is provided "as is," by Freddie Mac® with...
# 45  Not Seasonally Adjusted  The overnight bank funding rate is calculated ...
# 46  Not Seasonally Adjusted  The overnight bank funding is calculated using...
# 47  Not Seasonally Adjusted                                                NaN
# 48  Not Seasonally Adjusted                                                NaN
# 49  Not Seasonally Adjusted                                                NaN
# 50  Not Seasonally Adjusted                                                NaN
# 51  Not Seasonally Adjusted                                                NaN
# 52  Not Seasonally Adjusted                                                NaN
# 53  Not Seasonally Adjusted                                                NaN
# 54  Not Seasonally Adjusted                                                NaN
# 55  Not Seasonally Adjusted                                                NaN
# 56  Not Seasonally Adjusted                                                NaN
# 57  Not Seasonally Adjusted                                                NaN
# 58  Not Seasonally Adjusted                                                NaN
# 59  Not Seasonally Adjusted                                                NaN
# 60      Seasonally Adjusted  The Tech Pulse release has been discontinued a...
# 61  Not Seasonally Adjusted                                                NaN
# 62  Not Seasonally Adjusted                                                NaN
# 63  Not Seasonally Adjusted  The observations for the S&P 500 represent the...
# 64  Not Seasonally Adjusted  The breakeven inflation rate represents a meas...
# 65  Not Seasonally Adjusted  Series is calculated as the spread between 3-M...
# 66  Not Seasonally Adjusted  For further information, please refer to the B...
# 67  Not Seasonally Adjusted  For further information, please refer to the B...
# 68      Seasonally Adjusted  The freight transportation services index cons...
# 69      Seasonally Adjusted  The unemployment rate represents the number of...
# 70  Not Seasonally Adjusted  For additional details, including an analysis ...

# %%
train = pd.read_csv('data/observations_train.csv')
train
# Out:
#          series_id                         date  value
# 0           AAA10Y  2000-01-03 00:00:00.0000000   1.17
# 1           AAA10Y  2000-01-04 00:00:00.0000000   1.20
# 2           AAA10Y  2000-01-05 00:00:00.0000000   1.16
# 3           AAA10Y  2000-01-06 00:00:00.0000000   1.15
# 4           AAA10Y  2000-01-07 00:00:00.0000000   1.17
# ...            ...                          ...    ...
# 103299  WLEMUINDXD  2017-12-27 00:00:00.0000000  13.95
# 103300  WLEMUINDXD  2017-12-28 00:00:00.0000000  12.77
# 103301  WLEMUINDXD  2017-12-29 00:00:00.0000000  23.07
# 103302  WLEMUINDXD  2017-12-30 00:00:00.0000000  47.60
# 103303  WLEMUINDXD  2017-12-31 00:00:00.0000000  89.84
#
# [103304 rows x 3 columns]

# %%
train.rolling(window=3, center=True, min_periods=2).apply(lambda x: (x[0]+x[-1])/2, raw=True).isnull().sum()
# Out:
# value    5364
# dtype: int64

# %%
train[train.value.isnull()]
# Out:
#       series_id                         date  value
# 10       AAA10Y  2000-01-17 00:00:00.0000000    NaN
# 35       AAA10Y  2000-02-21 00:00:00.0000000    NaN
# 79       AAA10Y  2000-04-21 00:00:00.0000000    NaN
# 105      AAA10Y  2000-05-29 00:00:00.0000000    NaN
# 131      AAA10Y  2000-07-04 00:00:00.0000000    NaN
# ...         ...                          ...    ...
# 94337   TEDRATE  2017-09-04 00:00:00.0000000    NaN
# 94362   TEDRATE  2017-10-09 00:00:00.0000000    NaN
# 94395   TEDRATE  2017-11-23 00:00:00.0000000    NaN
# 94417   TEDRATE  2017-12-25 00:00:00.0000000    NaN
# 94418   TEDRATE  2017-12-26 00:00:00.0000000    NaN
#
# [2683 rows x 3 columns]

# %%
train.date = pd.to_datetime(train.date)

# %%
train.ffill().value.isnull().sum()
# Out:
# 0

# %%
df = train.pivot_table(columns='series_id', index='date').value
df.head()
# Out:
# series_id   AAA10Y  ASEANTOT  BAA10Y  BUSAPPWNSAUS  BUSAPPWNSAUSYY  \
# date
# 2000-01-02     NaN       NaN     NaN           NaN             NaN
# 2000-01-03    1.17       NaN    1.69           NaN             NaN
# 2000-01-04    1.20       NaN    1.72           NaN             NaN
# 2000-01-05    1.16       NaN    1.67           NaN             NaN
# 2000-01-06    1.15       NaN    1.67           NaN             NaN
#
# series_id   CBUSAPPWNSAUS  CBUSAPPWNSAUSYY  CUUR0000SA0R  DEXCHUS  DEXUSEU  \
# date
# 2000-01-02            NaN              NaN           NaN      NaN      NaN
# 2000-01-03            NaN              NaN           NaN   8.2798   1.0155
# 2000-01-04            NaN              NaN           NaN   8.2799   1.0309
# 2000-01-05            NaN              NaN           NaN   8.2798   1.0335
# 2000-01-06            NaN              NaN           NaN   8.2797   1.0324
#
# series_id   ...  PCUOMINOMIN  SFTPAGRM158SFRBSF  SP500  T10YIE  TEDRATE  \
# date        ...
# 2000-01-02  ...          NaN                NaN    NaN     NaN      NaN
# 2000-01-03  ...          NaN                NaN    NaN     NaN      NaN
# 2000-01-04  ...          NaN                NaN    NaN     NaN     0.77
# 2000-01-05  ...          NaN                NaN    NaN     NaN     0.75
# 2000-01-06  ...          NaN                NaN    NaN     NaN     0.78
#
# series_id   TLAACBW027NBOG  TLBACBW027NBOG  TSIFRGHT  UNRATE  WLEMUINDXD
# date
# 2000-01-02             NaN             NaN       NaN     NaN       59.69
# 2000-01-03             NaN             NaN       NaN     NaN       56.28
# 2000-01-04             NaN             NaN       NaN     NaN      253.20
# 2000-01-05        5628.536        5162.427       NaN     NaN       28.13
# 2000-01-06             NaN             NaN       NaN     NaN       25.59
#
# [5 rows x 68 columns]

# %%
train[train.series_id=='SP500'].date.describe(datetime_is_numeric=True)
# Out:
# count                             1795
# mean     2014-07-23 00:00:00.000000256
# min                2011-02-14 00:00:00
# 25%                2012-11-01 12:00:00
# 50%                2014-07-23 00:00:00
# 75%                2016-04-11 12:00:00
# max                2017-12-29 00:00:00
# Name: date, dtype: object

# %%
df.interpolate('time').isnull().sum()
# Out:
# series_id
# AAA10Y                   1
# ASEANTOT              1429
# BAA10Y                   1
# BUSAPPWNSAUS          2197
# BUSAPPWNSAUSYY        2561
# CBUSAPPWNSAUS         2197
# CBUSAPPWNSAUSYY       2561
# CUUR0000SA0R            30
# DEXCHUS                  1
# DEXUSEU                  1
# DEXUSUK                  1
# DFII10                1096
# DFII20                1668
# DFII30                3704
# DFII5                 1096
# DFII7                 1096
# DLTIIT                   1
# DPCREDIT              1103
# DPRIME                   1
# EECTOT                  30
# EFFR                   183
# EFFRVOL               5903
# FRGSHPUSM649NCIS        30
# GVIPT50002S             30
# GVIPT50030S             30
# GVIPT51000S             30
# GVIPT51100S             30
# GVIPT51110S             30
# GVIPT51120S             30
# GVIPT51200S             30
# GVIPT52000S             30
# GVIPT52100S             30
# GVIPT521A3S             30
# GVIPT52300S             30
# GVIPT54000S             30
# GVIPT54100S             30
# GVIPT54200S             30
# GVIPT54220S             30
# INFECTDISEMVTRACKD       0
# IOER                  3203
# IORR                  3203
# MEDCPIM158SFRBCLE       30
# MORTGAGE15US             5
# MORTGAGE30US             5
# OBFR                  5903
# OBFRVOL               5903
# PCUADLVWRADLVWR       2525
# PCUAINFOAINFO         2525
# PCUAMUMAMUM           2525
# PCUARETTRARETTR       2525
# PCUASHCASHC           2525
# PCUASTDSVASTDSV       2525
# PCUATRADEATRADE       2525
# PCUATRANSATRANS       2525
# PCUATRNWRATRNWR       2525
# PCUATTDSVATTDSV       2525
# PCUAWHLTRAWHLTR       2525
# PCUOMFGOMFG             30
# PCUOMINOMIN             30
# SFTPAGRM158SFRBSF       30
# SP500                 4061
# T10YIE                1096
# TEDRATE                  2
# TLAACBW027NBOG           3
# TLBACBW027NBOG           3
# TSIFRGHT                30
# UNRATE                  30
# WLEMUINDXD               0
# dtype: int64

# %%
sp500 = train[train.series_id=='SP500']
sp500 = sp500.set_index('date')
sp500.drop('series_id', axis=1)
sp500 = sp500.value.interpolate('time')

# %%
sp500.head(10)
# Out:
# date
# 2011-02-14    1332.3200
# 2011-02-15    1328.0100
# 2011-02-16    1336.3200
# 2011-02-17    1340.4300
# 2011-02-18    1343.0100
# 2011-02-21    1322.3325
# 2011-02-22    1315.4400
# 2011-02-23    1307.4000
# 2011-02-24    1306.1000
# 2011-02-25    1319.8800
# Name: value, dtype: float64

# %%
sp500.index.min()-pd.to_timedelta('1y')
# Out:
# Timestamp('2010-02-13 18:10:48')

# %%
one_week = pd.to_timedelta('1w')
one_month = pd.to_timedelta('30d')  # room to make it more precise?
one_year = pd.to_timedelta('1y')
two_years = pd.to_timedelta('2y')

y = train[train.series_id=='SP500']
y = y.set_index('date')
y = y.interpolate('time')
min_cutoff = sp500.index.min()-two_years

X = train[train.series_id!='SP500']
X = X.set_index('date')
# Only look at dates within two years from 2011
X = X[X.index>=min_cutoff]
X = X.pivot_table(index=X.index, columns='series_id').value
X = X.interpolate('time')

# Drop cols that cannot be filled with interpolation
drop_cols = X.isnull().mean(0).sort_values(ascending=False)
drop_cols = drop_cols[drop_cols>0.1].index
X = X.drop(drop_cols, axis=1)
# Only looking at weekdays ??
# X = X.loc[X.index.dayofweek<5]
X = X.bfill()  # better ways to do this?

# %%
#Function to compute additional derived features
#It iterates through each existing feature and compute key statistics (rolling) for multiple lookback periods.
def derive_features(df):
    features = df.columns
    #Iterate through each column in df
    for col in tqdm(features):
        if col != 'y':
            #Daily change
            df[col+'_ret'] = df[col].pct_change()
            df[col+'_diff'] = df[col].diff()
            #Lookback periods
            lookback = [5,21, 63, 126, 252]#1 week, 1 month, 1 quarter, half year, 1 year
            
            #Compute key statistics for each lookback period
            for i in lookback:
                df[col+'_ret_' + str(i)] = df[col]/df[col].shift(i)-1
                #Return-based
                df[col+'_rolling_mean_' + str(i)] = df[col+'_ret'].rolling(i).mean()
                df[col+'_rolling_median_' + str(i)] = df[col+'_ret'].rolling(i).median()
                df[col+'_rolling_stdev_' + str(i)] = df[col+'_ret'].rolling(i).std()
                df[col+ '_rolling_skew_' + str(i)] = df[col+'_ret'].rolling(i).skew()
                df[col+ '_rolling_kurt_' + str(i)] = df[col+'_ret'].rolling(i).kurt()
                df[col+ '_rolling_min_' + str(i)] = df[col+'_ret'].rolling(i).min()
                df[col+ '_rolling_max_' + str(i)] = df[col+'_ret'].rolling(i).max()
                df[col+ '_rolling_corr_' + str(i)] = df[col+'_ret'].rolling(i).corr()
                df[col+ '_ewma_' + str(i)] = pd.DataFrame.ewm(df[col], span= i).mean()
                #Relative level
                df[col+'_rel_lvl_mean_' + str(i)] = df[col]/df[col].rolling(i).mean()
                df[col+'_rel_lvl_min_' + str(i)] = df[col]/df[col].rolling(i).min()
                df[col+'_rel_lvl_max_' + str(i)] = df[col]/df[col].rolling(i).max()                        
    return df

# %%
X = derive_features(X)
# Out:
# 100%|██████████| 63/63 [00:36<00:00,  1.74it/s]

# %%
# Only looking at one year
min_cutoff = sp500.index.min()-one_year
X = X[X.index>=min_cutoff]
X = X.replace([np.inf, -np.inf], np.nan)

# Dropping cols with more than 1% null values
drop_cols = (X.isnull().mean(0))
drop_cols = drop_cols[drop_cols>0.01].index
X = X.drop(drop_cols, axis=1)
X = X.dropna()
X = X.reindex(y.index).ffill()
df_train = X

# %%
#Initialize and fit scaler
scaler = StandardScaler()
#Fit scaler using the training data
X = scaler.fit_transform(X)

# %%
idxs = np.random.choice(range(len(y)), 300)
MI_selector = SelectPercentile(mutual_info_classif, percentile=60)#Remove the lower 40%
MI_selector.fit(X[idxs],  y.iloc[idxs].value.values.astype(int))
# Out:
# SelectPercentile(percentile=60,
#                  score_func=<function mutual_info_classif at 0x12b20f790>)

# %%
X = MI_selector.transform(X)

# %%
#Rank the features by scores
plt.figure(figsize=(16, 14), dpi= 60)
feat_scores = pd.Series(MI_selector.scores_, index=df_train.columns)
top_feat = feat_scores.nlargest(10)[::-1]
top_feat.plot(kind='barh')
plt.title("Features with Highest Mutual Information", fontsize=20)
plt.xlabel('Feature Score', fontsize=16)
plt.ylabel('Feature', fontsize=16)
# plt.show()
plt.savefig('mutual_info.png', transparent=True)

# %%
print(X.shape, y.shape)
# Out:
# (1795, 2230) (1795, 2)

# %%
#Function to filter features based on correlation
#X_train and X_test inputs must be dataframes
#Corr_threshold is the cuttoff level for correlation coefficient
def correlation_filter(X_train,corr_threshold):
    
    #Compute correlation matrix
    corr_matrix = X_train.corr(method = "spearman").abs()
    
    # Select upper triangle of matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(np.bool))
    
    # Find index of feature columns with correlation greater than user-defined threshold
    to_drop = [column for column in upper.columns if any(upper[column] > corr_threshold)]
    
    # Drop features
    X_train_corr_filtered = X_train.drop(to_drop, axis = 1)
    
    return X_train_corr_filtered

#Helper function for heat map
def heat_map(corr_matrix,title):
    
    sns.set(font_scale = 1.0)
    f, ax = plt.subplots(figsize=(11, 9))
    sns.heatmap(corr_matrix, cmap= "YlGnBu", square=True, ax = ax)
    f.tight_layout()
    ax.set_title(title)

#Initialize dataframes
df_train_MI = pd.DataFrame(data = X,
                       index = y.index,
                       columns = df_train.columns[MI_selector.get_support()])

#Filter
X_train_corr = correlation_filter(df_train_MI,0.95)

#Correlation heatmap before/after removing highly correlated features (training set)
corr_matrix_before = df_train_MI.corr(method = "spearman").abs()
corr_matrix_after = X_train_corr.corr(method = "spearman").abs()

#Plot heatmaps
heat_map(corr_matrix_before, "Correlation Heat Map - Before Filtering")
heat_map(corr_matrix_after, "Correlation Heat Map - After Filtering")

#Summary
print("Correlation Filter Result:")
print("Number of features: ",X_train_corr.shape[1])
